# %% [markdown]
# ### Importing libraries

# %%
from pyspark.sql import SparkSession
import pandas as pd
import os
import geopandas as gpd
import folium

# %% [markdown]
# ## Understanding data

# %% [markdown]
# In Newyork City, all taxi vehicles are managed by TLC (Taxi and Limousine Commission). The TLC Trip Record data to public for research and study purposes. The dataset in this project is of Uber, Lyft and Via which are one of the leading taxi service providers in New York.

# %% [markdown]
# The entire dataset include 5 kinds of data:
# - **Dataset 1:**  *taxi_zone_lookup.csv* : stores taxi zones zip code and other relevant information.
# - **Dataset 2:**  *nyc 2021-01-01 to 2021-12-31.csv* : Daily weather data of New york for 2021
# - **Dataset 3:**  *taxi-zones* : folder contains the geospatial data of NYC taxi zones
# - **Dataset 4:**  *fhvhv_tripdata_2021-01.parquet to fhvhv_tripdata_2021-12.parquet* : 12 files. Containing data of taxi trips of each month.
# - **Dataset 5:**  *public_holidays.csv* : Contains list of public holidays in 2021
# - **Dataset 6:** *weather.csv* : Hourly weather data of 2021

# %% [markdown]
# ### Dataset 1: taxi_zone_lookup.csv

# %%
taxi_zone_lookup = pd.read_csv('dataset/taxi_zone_lookup.csv')

# %%
taxi_zone_lookup.sample(5)
# Out:
#      LocationID    Borough                Zone service_zone
# 111         112   Brooklyn          Greenpoint    Boro Zone
# 123         124     Queens        Howard Beach    Boro Zone
# 46           47      Bronx  Claremont/Bathgate    Boro Zone
# 224         225   Brooklyn  Stuyvesant Heights    Boro Zone
# 124         125  Manhattan           Hudson Sq  Yellow Zone

# %%
taxi_zone_lookup[taxi_zone_lookup['LocationID']==167]
# Out:
#      LocationID Borough                Zone service_zone
# 166         167   Bronx  Morrisania/Melrose    Boro Zone

# %%
taxi_zone_lookup.shape
# Out:
# (265, 4)

# %%
taxi_zone_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB

# %%
taxi_zone_lookup['Borough'].value_counts()
# Out:
# Borough
# Queens           69
# Manhattan        69
# Brooklyn         61
# Bronx            43
# Staten Island    20
# Unknown           2
# EWR               1
# Name: count, dtype: int64

# %%
taxi_zone_lookup['Zone'].value_counts()
# Out:
# Zone
# Governor's Island/Ellis Island/Liberty Island    3
# Corona                                           2
# Newark Airport                                   1
# Ocean Hill                                       1
# Parkchester                                      1
#                                                 ..
# Fordham South                                    1
# Forest Hills                                     1
# Forest Park/Highland Park                        1
# Fort Greene                                      1
# NV                                               1
# Name: count, Length: 261, dtype: int64

# %%
taxi_zone_lookup['service_zone'].value_counts()
# Out:
# service_zone
# Boro Zone      205
# Yellow Zone     55
# Airports         2
# EWR              1
# Name: count, dtype: int64

# %%
for zone in taxi_zone_lookup['service_zone'].unique():
    print(zone)
    print(taxi_zone_lookup[taxi_zone_lookup['service_zone']==zone]['Borough'].value_counts())
    print()
# Out:
# EWR
# Borough
# EWR    1
# Name: count, dtype: int64
#
# Boro Zone
# Borough
# Queens           67
# Brooklyn         61
# Bronx            43
# Staten Island    20
# Manhattan        14
# Name: count, dtype: int64
#
# Yellow Zone
# Borough
# Manhattan    55
# Name: count, dtype: int64
#
# Airports
# Borough
# Queens    2
# Name: count, dtype: int64
#
# nan
# Series([], Name: count, dtype: int64)

# %%
taxi_zone_lookup[taxi_zone_lookup['service_zone'].isnull()]
# Out:
#      LocationID  Borough Zone service_zone
# 263         264  Unknown   NV          NaN
# 264         265  Unknown  NaN          NaN

# %% [markdown]
# ### Dataset 2: nyc weather

# %%
weather = pd.read_csv('dataset/nyc_2021_weather.csv')

# %%
weather.sample(5)
# Out:
#     name address              resolvedAddress    datetime  temp  feelslike
# 317  nyc     nyc  New York, NY, United States  2021-11-14   6.5        4.4  \
# 141  nyc     nyc  New York, NY, United States  2021-05-22  25.3       24.9
# 130  nyc     nyc  New York, NY, United States  2021-05-11  14.3       14.3
# 28   nyc     nyc  New York, NY, United States  2021-01-29  -6.2      -14.1
# 5    nyc     nyc  New York, NY, United States  2021-01-06   3.0       -0.6
#
#       dew  humidity  precip  precipprob  ... snow  snowdepth  windgust
# 317  -0.5      61.3    0.32         100  ...  0.0        0.0      42.5  \
# 141  12.7      47.2    0.00           0  ...  0.0        0.0      33.5
# 130   0.9      42.8    0.00           0  ...  0.0        0.0      50.5
# 28  -17.2      41.7    0.00           0  ...  0.0        1.4      62.2
# 5    -3.3      63.7    0.00           0  ...  0.0        0.0      44.7
#
#      windspeed  winddir  sealevelpressure  cloudcover  visibility  uvindex
# 317       23.8    240.1            1012.0        42.7        15.9        4  \
# 141       21.2    251.1            1021.5        43.8        16.0        8
# 130       23.5    300.8            1016.5        50.3        16.0        9
# 28        43.3    303.8            1019.8        18.1        16.0        6
# 5         28.8    300.9            1015.0        46.6        16.0        5
#
#      severerisk
# 317         NaN
# 141         NaN
# 130         NaN
# 28          NaN
# 5           NaN
#
# [5 rows x 21 columns]

# %%
weather.shape
# Out:
# (365, 21)

# %%
weather.columns
# Out:
# Index(['name', 'address', 'resolvedAddress', 'datetime', 'temp', 'feelslike',
#        'dew', 'humidity', 'precip', 'precipprob', 'preciptype', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'sealevelpressure',
#        'cloudcover', 'visibility', 'uvindex', 'severerisk'],
#       dtype='object')

# %%
weather[['name','address','resolvedAddress']].value_counts()
# Out:
# name  address  resolvedAddress
# nyc   nyc      New York, NY, United States    365
# Name: count, dtype: int64

# %%
# Have only one value
drop_columns = ['name','address','resolvedAddress']

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              365 non-null    object
#  1   address           365 non-null    object
#  2   resolvedAddress   365 non-null    object
#  3   datetime          365 non-null    object
#  4   temp              365 non-null    float64
#  5   feelslike         365 non-null    float64
#  6   dew               365 non-null    float64
#  7   humidity          365 non-null    float64
#  8   precip            365 non-null    float64
#  9   precipprob        365 non-null    int64
#  10  preciptype        152 non-null    object
#  11  snow              365 non-null    float64
#  12  snowdepth         365 non-null    float64
#  13  windgust          292 non-null    float64
#  14  windspeed         365 non-null    float64
#  15  winddir           365 non-null    float64
#  16  sealevelpressure  365 non-null    float64
#  17  cloudcover        365 non-null    float64
#  18  visibility        365 non-null    float64
#  19  uvindex           365 non-null    int64
#  20  severerisk        0 non-null      float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 60.0+ KB

# %%
# Columns with null values = [preciptype, windgust, severerisk]

# %%
drop_columns.append('severerisk')

# %% [markdown]
# **Filling missing values**

# %%
# Preciptype

# %%
weather['preciptype'].value_counts()
# Out:
# preciptype
# rain         132
# rain,snow     17
# snow           3
# Name: count, dtype: int64

# %%
weather[weather['preciptype']=='rain'][['precip','precipprob']].describe()
# Out:
#            precip  precipprob
# count  132.000000       132.0
# mean     9.790530       100.0
# std     19.339919         0.0
# min      0.040000       100.0
# 25%      0.802500       100.0
# 50%      3.665000       100.0
# 75%     11.725000       100.0
# max    165.380000       100.0

# %%
weather[weather['preciptype']=='rain,snow'][['precip','precipprob']].describe()
# Out:
#           precip  precipprob
# count  17.000000        17.0
# mean    6.221176       100.0
# std    10.446702         0.0
# min     0.070000       100.0
# 25%     0.480000       100.0
# 50%     2.660000       100.0
# 75%     5.090000       100.0
# max    39.960000       100.0

# %%
weather[weather['preciptype']=='snow'][['precip','precipprob']].describe()
# Out:
#           precip  precipprob
# count   3.000000         3.0
# mean    4.356667       100.0
# std     5.677960         0.0
# min     0.270000       100.0
# 25%     1.115000       100.0
# 50%     1.960000       100.0
# 75%     6.400000       100.0
# max    10.840000       100.0

# %%
weather[(weather['preciptype'].isnull()) & (weather['precipprob']==100)]
# Out:
# Empty DataFrame
# Columns: [name, address, resolvedAddress, datetime, temp, feelslike, dew, humidity, precip, precipprob, preciptype, snow, snowdepth, windgust, windspeed, winddir, sealevelpressure, cloudcover, visibility, uvindex, severerisk]
# Index: []
#
# [0 rows x 21 columns]

# %%
weather[weather['preciptype'].isnull()][['precip','precipprob']].describe()
# Out:
#        precip  precipprob
# count   213.0       213.0
# mean      0.0         0.0
# std       0.0         0.0
# min       0.0         0.0
# 25%       0.0         0.0
# 50%       0.0         0.0
# 75%       0.0         0.0
# max       0.0         0.0

# %% [markdown]
# The above analysis indicate that all null values in preciptype are dates with clear weather

# %%
weather['preciptype'] = weather['preciptype'].fillna('clear')

# %%
# windgust

# %% [markdown]
# According to U.S. weather observing practice, gusts are reported when the peak wind speed reaches at least 16 knots and the variation in wind speed between the peaks and lulls is at least 9 knots. The duration of a gust is usually less than 20 seconds.
#
# Since we don't have hourly data there is no point of using windgust for our problem statement. It can also hinder with our predictions.

# %%
drop_columns.append('windgust')

# %%
weather[(weather['snow']>0) | (weather['snowdepth']>0)][['snow','snowdepth']].describe()
# Out:
#             snow  snowdepth
# count  56.000000  56.000000
# mean    2.130357  10.737500
# std     3.280794   9.109646
# min     0.000000   0.100000
# 25%     0.000000   1.700000
# 50%     1.000000   9.100000
# 75%     2.525000  18.325000
# max    16.100000  31.700000

# %%
drop_columns
# Out:
# ['name', 'address', 'resolvedAddress', 'severerisk', 'windgust']

# %%
weather = weather.drop(columns=drop_columns)

# %% [markdown]
# ### Dataset 3: taxi-zones

# %%
os.listdir('dataset/taxi_zones')
# Out:
# ['taxi_zones.dbf',
#  'taxi_zones.shp.xml',
#  'taxi_zones.shp',
#  'taxi_zones.sbx',
#  'taxi_zones.shx',
#  'location_lat_long.csv',
#  'taxi_zones.prj',
#  'taxi_zones.sbn']

# %%
gdf = gpd.read_file(f"dataset/taxi_zones/taxi_zones.shp")
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int64
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int64
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(2)
# memory usage: 14.5+ KB

# %%
gdf.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID
# 0         1    0.116357    0.000782           Newark Airport           1  \
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.770 256767.698, 1026495.593 ...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.310 144283.336, 936046.565 14...

# %%
gdf['centroid'] = gdf.centroid
gdf = gdf.to_crs(epsg=4326)
gdf['centroid'] = gdf['centroid'].to_crs(epsg=4326)

# %%
m1 = folium.Map(location=[40.70, -73.94], zoom_start=12, tiles="Cartodb Positron")

# add centroid marker to each taxi zones
latitudes = []
longitudes = []

for _, r in gdf.iterrows():
    lat = r['centroid'].y
    latitudes.append(lat)
    lon = r['centroid'].x
    longitudes.append(lon)
    sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.0001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j,style_function=lambda x: {'fillColor': 'green'})
    folium.Popup(r['zone']).add_to(geo_j)
    geo_j.add_to(m1)

    
# markers_group.add_to(m)
gdf['c_latitude'] = latitudes
gdf['c_longitude'] = longitudes
# m1.save('maps/gdf.html') # save as html
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b54e634a241dc2cf394430e5b7546f0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b54e634a241dc2cf394430e5b7546f0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b54e634a241dc2cf394430e5b7546f0c = L.map(
#                 &quot;map_b54e634a241dc2cf394430e5b7546f0c&quot;,
#                 {
#                     center: [40.7, -73.94],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2097c3f7e1637b5f2b361a85c6fb90b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f2097c3f7e1637b5f2b361a85c6fb90b.addTo(map_b54e634a241dc2cf394430e5b7546f0c);
#
#
#         function geo_json_982dab4e8202fe6a616744971baef8df_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_982dab4e8202fe6a616744971baef8df_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_982dab4e8202fe6a616744971baef8df = L.geoJson(null, {
#                 onEachFeature: geo_json_982dab4e8202fe6a616744971baef8df_onEachFeature,
#
#                 style: geo_json_982dab4e8202fe6a616744971baef8df_styler,
#         });
#
#         function geo_json_982dab4e8202fe6a616744971baef8df_add (data) {
#             geo_json_982dab4e8202fe6a616744971baef8df
#                 .addData(data);
#         }
#             geo_json_982dab4e8202fe6a616744971baef8df_add({&quot;bbox&quot;: [-74.18998799999997, 40.67101100000013, -74.15306999999996, 40.70796500000009], &quot;features&quot;: [{&quot;bbox&quot;: [-74.18998799999997, 40.67101100000013, -74.15306999999996, 40.70796500000009], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.18445299999996, 40.694996000000096], [-74.18438099999997, 40.69587800000008], [-74.18350799999996, 40.69870400000011], [-74.18315699999994, 40.70121500000007], [-74.18313899999998, 40.70262800000008], [-74.18284199999994, 40.70346500000007], [-74.18220299999996, 40.70414000000008], [-74.18157299999996, 40.704500000000074], [-74.17699199999998, 40.70613800000009], [-74.17565999999994, 40.70738000000007], [-74.17388699999998, 40.707731000000116], [-74.17133999999999, 40.70796500000009], [-74.16081899999995, 40.70764100000011], [-74.15387999999996, 40.70532800000009], [-74.15306999999996, 40.70528300000011], [-74.15513999999996, 40.701557000000065], [-74.16290699999996, 40.68987500000006], [-74.16417599999994, 40.69008200000011], [-74.16479699999996, 40.68975800000008], [-74.16587699999997, 40.68787700000011], [-74.16580499999998, 40.68715700000009], [-74.16604799999999, 40.68655400000008], [-74.17283399999997, 40.67656400000008], [-74.17709099999996, 40.671785000000085], [-74.17754999999994, 40.6714250000001], [-74.17862999999994, 40.67103800000008], [-74.17933199999999, 40.67101100000013], [-74.18030399999998, 40.67129900000006], [-74.18384999999995, 40.67264900000007], [-74.18503799999996, 40.67336000000008], [-74.18935799999997, 40.679759000000075], [-74.18991599999998, 40.681541000000074], [-74.18998799999997, 40.68317900000009], [-74.18940299999997, 40.68809300000006], [-74.18922299999997, 40.688624000000104], [-74.18870099999998, 40.68944300000006], [-74.18563199999994, 40.691648000000086], [-74.18445299999996, 40.694996000000096]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_616c9eff04cbcab92b90020e2f2a2b2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d73f12e78e120e73df8e3729f300e1c = $(`&lt;div id=&quot;html_6d73f12e78e120e73df8e3729f300e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Newark Airport&lt;/div&gt;`)[0];
#                 popup_616c9eff04cbcab92b90020e2f2a2b2d.setContent(html_6d73f12e78e120e73df8e3729f300e1c);
#
#
#
#         geo_json_982dab4e8202fe6a616744971baef8df.bindPopup(popup_616c9eff04cbcab92b90020e2f2a2b2d)
#         ;
#
#
#
#
#             geo_json_982dab4e8202fe6a616744971baef8df.addTo(map_b54e634a241dc2cf394430e5b7546f0c);
#
#
#         function geo_json_3a855e71b88a8a34591a66e084657acb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_3a855e71b88a8a34591a66e084657acb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3a855e71b88a8a34591a66e084657acb = L.geoJs

# %%
len(latitudes)
# Out:
# 263

# %%
# gdf.to_csv("dataset/taxi_zones/location_lat_long.csv")

# %% [markdown]
# ### Dataset 4: fhvhv_tripdata_2021-01.parquet to fhvhv_tripdata_2021-12.parquet

# %%
spark = SparkSession.builder.appName("Taxi").getOrCreate()
# Out:
# 24/02/08 09:01:23 WARN Utils: Your hostname, Afnanurrahim.local resolves to a loopback address: 127.0.0.1; using 192.168.29.10 instead (on interface en0)
# 24/02/08 09:01:23 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/02/08 09:01:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.29.10:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Taxi</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
os.listdir('dataset')
# Out:
# ['september.parquet',
#  '.DS_Store',
#  'july.parquet',
#  'taxi_zones',
#  'new_york_weather.csv',
#  'april.parquet',
#  'data_dictionary_trip_records_hvfhs.pdf',
#  'nyc_2021_weather.csv',
#  'october.parquet',
#  'public_holidays.csv',
#  'june.parquet',
#  'taxi_zone_lookup.csv',
#  'february.parquet',
#  'weather_processed.csv',
#  'december.parquet',
#  'august.parquet',
#  '.ipynb_checkpoints',
#  'november.parquet',
#  'may.parquet',
#  'march.parquet',
#  'working_parquet_format.pdf',
#  'january.parquet']

# %%
class PDF(object):
    def __init__(self, pdf, size=(200,200)):
        self.pdf = pdf
        self.size = size

    def _repr_html_(self):
        return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

    def _repr_latex_(self):
        return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %%
PDF('dataset/data_dictionary_trip_records_hvfhs.pdf',size=(800,650))
# Out:
# \includegraphics[width=1.0\textwidth]{dataset/data_dictionary_trip_records_hvfhs.pdf}

# %%
file_rename = {'fhvhv_tripdata_2021-03.parquet': 'march.parquet',
 'fhvhv_tripdata_2021-12.parquet': 'december.parquet',
 'fhvhv_tripdata_2021-02.parquet': 'february.parquet',
 'fhvhv_tripdata_2021-09.parquet': 'september.parquet',
 'fhvhv_tripdata_2021-10.parquet': 'october.parquet',
 'fhvhv_tripdata_2021-11.parquet': 'november.parquet',
 'fhvhv_tripdata_2021-01.parquet': 'january.parquet',
 'fhvhv_tripdata_2021-08.parquet': 'august.parquet',
 'fhvhv_tripdata_2021-04.parquet': 'april.parquet',
 'fhvhv_tripdata_2021-05.parquet': 'may.parquet',
 'fhvhv_tripdata_2021-07.parquet': 'july.parquet',
 'fhvhv_tripdata_2021-06.parquet': 'june.parquet'}

# %%
# for file in file_rename:
#     os.rename(f'dataset/{file}', f'dataset/{file_rename[file]}')

# %%
files = [f for f in os.listdir('dataset') if f.endswith('.parquet')]

# %%
len(files)
# Out:
# 12

# %%
jan_df = spark.read.parquet('dataset/january.parquet')
feb_df = spark.read.parquet('dataset/february.parquet')
march_df = spark.read.parquet('dataset/march.parquet')
april_df = spark.read.parquet('dataset/april.parquet')
may_df = spark.read.parquet('dataset/may.parquet')
june_df = spark.read.parquet('dataset/june.parquet')
july_df = spark.read.parquet('dataset/july.parquet')
aug_df = spark.read.parquet('dataset/august.parquet')
sep_df = spark.read.parquet('dataset/september.parquet')
oct_df = spark.read.parquet('dataset/october.parquet')
nov_df = spark.read.parquet('dataset/november.parquet')
dec_df = spark.read.parquet('dataset/december.parquet')

# %%
month_var = [jan_df, feb_df, march_df, april_df, may_df, june_df, july_df, aug_df, sep_df, oct_df, nov_df, dec_df,]

# %%
for month in month_var:
    print(f"shape: ({month.count()}, {len(month.columns)})")
# Out:
# shape: (11908468, 24)
# shape: (11613942, 24)
# shape: (14227393, 24)
# shape: (14111371, 24)
# shape: (14719171, 24)
# shape: (14961892, 24)
# shape: (15027174, 24)
# shape: (14499696, 24)
# shape: (14886055, 24)
# shape: (16545356, 24)
# shape: (16041639, 24)
# shape: (16054495, 24)

# %%
total = 0
for month in month_var:
    total+= month.count()

# %%
total
# Out:
# 174596652

# %%
combined_df = jan_df.union(feb_df)

for month in month_var[2:]:
    combined_df = combined_df.union(month)

# %%
f"shape: ({combined_df.count()}, {len(combined_df.columns)})"
# Out:
# 'shape: (174596652, 24)'

# %%
combined_df.dtypes
# Out:
# [('hvfhs_license_num', 'string'),
#  ('dispatching_base_num', 'string'),
#  ('originating_base_num', 'string'),
#  ('request_datetime', 'timestamp_ntz'),
#  ('on_scene_datetime', 'timestamp_ntz'),
#  ('pickup_datetime', 'timestamp_ntz'),
#  ('dropoff_datetime', 'timestamp_ntz'),
#  ('PULocationID', 'bigint'),
#  ('DOLocationID', 'bigint'),
#  ('trip_miles', 'double'),
#  ('trip_time', 'bigint'),
#  ('base_passenger_fare', 'double'),
#  ('tolls', 'double'),
#  ('bcf', 'double'),
#  ('sales_tax', 'double'),
#  ('congestion_surcharge', 'double'),
#  ('airport_fee', 'double'),
#  ('tips', 'double'),
#  ('driver_pay', 'double'),
#  ('shared_request_flag', 'string'),
#  ('shared_match_flag', 'string'),
#  ('access_a_ride_flag', 'string'),
#  ('wav_request_flag', 'string'),
#  ('wav_match_flag', 'string')]

# %%
combined_df.groupBy('hvfhs_license_num').count().show()
# Out:
# +-----------------+---------+
# |hvfhs_license_num|    count|
# +-----------------+---------+
# |           HV0004|   891819|
# |           HV0005| 47575769|
# |           HV0003|126129064|
# +-----------------+---------+

# %% [markdown]
# - HV0003: Uber
# - HV0004: Via
# - HV0005: Lyft

# %%
combined_df.select('originating_base_num').distinct().count()
# Out:
# 44

# %%
combined_df.select('dispatching_base_num').distinct().count()
# Out:
# 34

# %%
combined_df.select('originating_base_num').distinct().show()
# Out:
# [Stage 102:=====================================================> (94 + 2) / 96]
# +--------------------+
# |originating_base_num|
# +--------------------+
# |              B02876|
# |              B00887|
# |              B03136|
# |              B02877|
# |              B02869|
# |              B02883|
# |              B02835|
# |              B02884|
# |              B02729|
# |              B02880|
# |              B02878|
# |              B02836|
# |              B02872|
# |              B02512|
# |              B02867|
# |              B02866|
# |              B02871|
# |              B02889|
# |              B02826|
# |              B02026|
# +--------------------+
# only showing top 20 rows

# %%
combined_df.select('dispatching_base_num').distinct().show()
# Out:
# [Stage 105:======================================================>(95 + 1) / 96]
# +--------------------+
# |dispatching_base_num|
# +--------------------+
# |              B02876|
# |              B03136|
# |              B02877|
# |              B02869|
# |              B02883|
# |              B02835|
# |              B02884|
# |              B02880|
# |              B02878|
# |              B02836|
# |              B02872|
# |              B02512|
# |              B02867|
# |              B02866|
# |              B02871|
# |              B02889|
# |              B02844|
# |              B02510|
# |              B02888|
# |              B02682|
# +--------------------+
# only showing top 20 rows

# %%
combined_df.filter(combined_df.originating_base_num.isNull()).count()
# Out:
# 48429487

# %%
combined_df.filter(combined_df.dispatching_base_num.isNull()).count()
# Out:
# 0

# %%
combined_df.filter((combined_df.originating_base_num.isNotNull()) &
                   (combined_df.originating_base_num != combined_df.dispatching_base_num)).count()
# Out:
# 44376

# %%
org_collect = combined_df.select('originating_base_num').distinct().collect()
disp_collect = combined_df.select('dispatching_base_num').distinct().collect()

# %%
org_base = [row.originating_base_num for row in org_collect]
disp_base = [row.dispatching_base_num for row in disp_collect]

# %%
[value for value in org_base if value not in disp_base]
# Out:
# ['B00887',
#  'B02729',
#  'B02826',
#  'B02026',
#  'B00692',
#  'B00457',
#  'B03153',
#  'B00446',
#  'B02390',
#  'B01985',
#  None]

# %%
[value for value in disp_base if value not in org_base]
# Out:
# ['B02844']

# %%
spark.sparkContext.stop()

# %% [markdown]
# ### Dataset 5: public_holidays.csv

# %%
holidays = pd.read_csv('dataset/public_holidays.csv', parse_dates=['Date'])

# %%
holidays
# Out:
#          Date       Day                              Holiday
# 0  2021-01-01    Friday                       New Year's Day
# 1  2021-01-18    Monday  Birthday of Martin Luther King, Jr.
# 2  2021-02-12    Friday                   Lincoln's Birthday
# 3  2021-02-15    Monday                Washington's Birthday
# 4  2021-05-31    Monday                         Memorial Day
# 5  2021-07-05    Monday                     Independence Day
# 6  2021-09-06    Monday                            Labor Day
# 7  2021-10-11    Monday                         Columbus Day
# 8  2021-11-02   Tuesday                         Election Day
# 9  2021-11-11  Thursday                         Veterans Day
# 10 2021-11-25  Thursday                     Thanksgiving Day
# 11 2021-12-25  Saturday                            Christmas

# %%
holidays.dtypes
# Out:
# Date       datetime64[ns]
# Day                object
# Holiday            object
# dtype: object

# %% [markdown]
# ### Dataset 6: weather.csv

# %%
weather = pd.read_csv('dataset/new_york_weather.csv')
weather.head()
# Out:
#    Unnamed: 0             valid  tmpf  dwpf   relh   drct  sknt  p01i   alti
# 0           0  2021-01-01 00:51  40.0  26.1  57.47  320.0  13.0   0.0  30.34  \
# 1           1  2021-01-01 01:51  39.0  24.1  54.77  350.0   9.0   0.0  30.35
# 2           2  2021-01-01 02:51  36.0  24.1  61.62  340.0   7.0   0.0  30.38
# 3           3  2021-01-01 03:51  36.0  25.0  63.98  340.0  10.0   0.0  30.41
# 4           4  2021-01-01 04:51  35.0  24.1  63.86  350.0   9.0   0.0  30.42
#
#      mslp  ...    skyl2  skyl3 skyl4 wxcodes peak_wind_gust peak_wind_drct
# 0  1027.4  ...  15000.0    NaN   NaN     NaN            NaN            NaN  \
# 1  1027.8  ...  17000.0    NaN   NaN     NaN            NaN            NaN
# 2  1028.8  ...  25000.0    NaN   NaN     NaN            NaN            NaN
# 3  1029.7  ...  25000.0    NaN   NaN     NaN            NaN            NaN
# 4  1030.0  ...  25000.0    NaN   NaN     NaN            NaN            NaN
#
#    peak_wind_time   feel                                              metar
# 0             NaN  31.69  KJFK 010051Z 32013KT 10SM FEW030 OVC150 04/M03...  \
# 1             NaN  32.22  KJFK 010151Z 35009KT 10SM FEW030 SCT170 04/M04...
# 2             NaN  29.65  KJFK 010251Z 34007KT 10SM FEW160 FEW250 02/M04...
# 3             NaN  27.98  KJFK 010351Z 34010KT 10SM FEW160 FEW250 02/M04...
# 4             NaN  27.37  KJFK 010451Z 35009KT 10SM FEW170 FEW250 02/M04...
#
#    snowdepth
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 27 columns]

# %%
weather.dtypes
# Out:
# Unnamed: 0          int64
# valid              object
# tmpf              float64
# dwpf              float64
# relh              float64
# drct              float64
# sknt              float64
# p01i              float64
# alti              float64
# mslp              float64
# vsby              float64
# gust              float64
# skyc1              object
# skyc2              object
# skyc3              object
# skyc4              object
# skyl1             float64
# skyl2             float64
# skyl3             float64
# skyl4             float64
# wxcodes            object
# peak_wind_gust    float64
# peak_wind_drct    float64
# peak_wind_time     object
# feel              float64
# metar              object
# snowdepth         float64
# dtype: object

# %%
weather.isnull().sum()
# Out:
# Unnamed: 0           0
# valid                0
# tmpf                 0
# dwpf                 0
# relh                 0
# drct                72
# sknt                 4
# p01i               776
# alti                 0
# mslp               950
# vsby                 1
# gust              8359
# skyc1                1
# skyc2             3606
# skyc3             6831
# skyc4             8976
# skyl1              447
# skyl2             3606
# skyl3             6831
# skyl4             8976
# wxcodes           8104
# peak_wind_gust    8704
# peak_wind_drct    8704
# peak_wind_time    8704
# feel                 0
# metar                0
# snowdepth         9608
# dtype: int64

# %%
# weather.station.value_counts()

# %%
# weather = weather.drop(columns=['ice_accretion_1hr', 'ice_accretion_3hr', 'ice_accretion_6hr', 'station'])

# %%
# weather.to_csv('dataset/new_york_weather.csv')
